# %%
import pandas as pd

schools_data = "Resources/schools_complete.csv"
students_data = "Resources/students_complete.csv"

# Read data files into DataFrames.
schools_df = pd.read_csv(schools_data)
students_df = pd.read_csv(students_data)

# %%
# Print start of schools file
schools_df.head()
# Out:
#    School ID            school_name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
# Print start of students file
students_df.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
# Merge the datasets with a left join.  
full_df = pd.merge(students_df, schools_df, how="left", on="school_name")
full_df.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
# Check key columns for typos and missing data.
print(full_df["gender"].value_counts())
print(full_df["grade"].unique())
print(full_df["school_name"].unique())
print(full_df["reading_score"].unique())
print(full_df["math_score"].unique())
# Out:
# F    19735
# M    19435
# Name: gender, dtype: int64
# ['9th' '12th' '11th' '10th']
# ['Huang High School' 'Figueroa High School' 'Shelton High School'
#  'Hernandez High School' 'Griffin High School' 'Wilson High School'
#  'Cabrera High School' 'Bailey High School' 'Holden High School'
#  'Pena High School' 'Wright High School' 'Rodriguez High School'
#  'Johnson High School' 'Ford High School' 'Thomas High School']
# [66 94 90 67 97 82 96 95 78 64 71 85 88 74 89 91 99 81 92 63 80 73 93 65
#  76 79 75 77 69 83 72 87 70 84 86 68 98]
# [79 61 60 58 84 94 80 69 87 70 77 67 88 55 75 89 68 73 85 99 65 90 74 76
#  66 95 93 59 81 56 78 71 72 57 82 62 63 86 98 91 92 97 83 96 64]

# %%
# Print statistical overview of DataFrame.
full_df.describe()
# Out:
#          Student ID  reading_score    math_score     School ID          size  \
# count  39170.000000    39170.00000  39170.000000  39170.000000  39170.000000
# mean   19584.500000       81.87784     78.985371      6.978172   3332.957110
# std    11307.549359       10.23958     12.309968      4.444329   1323.914069
# min        0.000000       63.00000     55.000000      0.000000    427.000000
# 25%     9792.250000       73.00000     69.000000      3.000000   1858.000000
# 50%    19584.500000       82.00000     79.000000      7.000000   2949.000000
# 75%    29376.750000       91.00000     89.000000     11.000000   4635.000000
# max    39169.000000       99.00000     99.000000     14.000000   4976.000000
#
#              budget
# count  3.917000e+04
# mean   2.117241e+06
# std    8.749987e+05
# min    2.480870e+05
# 25%    1.081356e+06
# 50%    1.910635e+06
# 75%    3.022020e+06
# max    3.124928e+06

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
# Compute total schools, students, and budget and compute average math and reading scores for district.
total_schools = len(full_df["school_name"].unique())
total_students = len(full_df["student_name"].unique())
total_budget = full_df["budget"].unique().sum()
avg_math = full_df["math_score"].mean()
avg_reading = full_df["reading_score"].mean()

# Compute percentage of students in district passing math and reading.
percent_passing_math = len(full_df.loc[full_df["math_score"] >= 70])/total_students*100
percent_passing_reading = len(full_df.loc[full_df["reading_score"] >= 70])/total_students*100
percent_passing_overall = len(full_df.loc[(full_df["math_score"] >=70) & (full_df["reading_score"] >= 70)])/total_students*100

# %%
# Store district stats to DataFrame.
district_dict = [{"Total Schools": total_schools, "Total Students": total_students, "Total Budget": total_budget, "Average Math Score": avg_math, "Average Reading Score": avg_reading, "% Passing Math": percent_passing_math, "% Passing Reading": percent_passing_reading, "% Passing Overall": percent_passing_overall}]
district_df = pd.DataFrame(district_dict, columns = ["Total Schools", "Total Students", "Total Budget", "Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "% Passing Overall"])
district_df.head()
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           32715      24649428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Passing Overall
# 0               81.87784       89.775332         102.735748          78.031484

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
# grouped_df[‘gender_percentage’]=(grouped_df[‘gender_count’])/(grouped_df[‘gender_count’].sum()) * 100
school_summary_df = full_df.groupby(["school_name"]).agg({"type": "first", "size": "sum", "budget": "sum", "math_score": "sum", "reading_score": "sum"})
school_summary_df["Per Student Budget"] = (school_summary_df["budget"])/(school_summary_df["size"])
school_summary_df["Average Math Score"] = (school_summary_df["math_score"])/(school_summary_df["size"])
school_summary_df["Average Reading Score"] = (school_summary_df["reading_score"])/(school_summary_df["size"])
school_summary_df["% Passing Math"] = len(full_df.loc[full_df["math_score"] >= 70])/(school_summary_df["size"])*100
school_summary_df["% Passing Reading"] = len(full_df.loc[full_df["reading_score"] >= 70])/(school_summary_df["size"])*100
school_summary_df["% Passing Overall"] = len(full_df.loc[(full_df["math_score"] >=70) & (full_df["reading_score"] >= 70)])/total_students*100
school_summary_df
# Out:
#                            type      size       budget  math_score  \
# school_name
# Bailey High School     District  24760576  15549641728      383393
# Cabrera High School     Charter   3452164   2009159448      154329
# Figueroa High School   District   8696601   5557128039      226223
# Ford High School       District   7502121   4831365924      211184
# Griffin High School     Charter   2155024   1346890000      122360
# Hernandez High School  District  21483225  14007062700      358238
# Holden High School      Charter    182329    105933149       35784
# Huang High School      District   8508889   5573322295      223528
# Johnson High School    District  22667121  14733628650      366942
# Pena High School        Charter    925444    563595396       80654
# Rodriguez High School  District  15992001  10186904637      307294
# Shelton High School     Charter   3101121   1860672600      146796
# Thomas High School      Charter   2673225   1705517550      136389
# Wilson High School      Charter   5212089   3012587442      190115
# Wright High School      Charter   3240000   1888920000      150628
#
#                        reading_score  Per Student Budget  Average Math Score  \
# school_name
# Bailey High School            403225               628.0            0.015484
# Cabrera High School           156027               582.0            0.044705
# Figueroa High School          239335               639.0            0.026013
# Ford High School              221164               644.0            0.028150
# Griffin High School           123043               625.0            0.056779
# Hernandez High School         375131               652.0            0.016675
# Holden High School             35789               581.0            0.196261
# Huang High School             236810               655.0            0.026270
# Johnson High School           385481               650.0            0.016188
# Pena High School               80851               609.0            0.087152
# Rodriguez High School         322898               637.0            0.019215
# Shelton High School           147441               600.0            0.047336
# Thomas High School            137093               638.0            0.051020
# Wilson High School            191748               578.0            0.036476
# Wright High School            151119               583.0            0.046490
#
#                        Average Reading Score  % Passing Math  \
# school_name
# Bailey High School